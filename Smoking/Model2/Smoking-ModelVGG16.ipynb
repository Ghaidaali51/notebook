# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from keras.layers import (
    Dense, Conv2D, GlobalAveragePooling2D, MaxPooling2D, Flatten, Rescaling, Input
) 
from keras.models import Sequential
# tensorflow 
from tensorflow.keras.utils import image_dataset_from_directory
import tensorflow as tf

# utils 
import numpy as np 
import random 

# vis
# import seaborn as sns
#import cv2 
import matplotlib.pyplot as plt


# sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

from tensorflow.keras.optimizers import Adam

# %%
# load data from directory

# %%
img_size = (150, 150)

def img_to_tf_dataset(path, labels='inferred', img_size=img_size, subset="training"):
    """ Fetch images assign label to them based on folders tree"""
    dataset = image_dataset_from_directory(
        directory=path,
        labels=labels , # labels generated from folder structure
        image_size=img_size,
        validation_split=0.2,
        subset=subset,
        seed=123,
        # default batch size 32
    )
    return dataset

# %%
train_ds = img_to_tf_dataset('data')
# Out:
# Found 5196 files belonging to 2 classes.
# Using 4157 files for training.

# %%
val_ds = img_to_tf_dataset('data', subset='validation')
# Out:
# Found 5196 files belonging to 2 classes.
# Using 1039 files for validation.

# %%
NUM_CLS = len(val_ds.class_names)
CLS_NAMES = val_ds.class_names
CLS_NAMES
# Out:
# ['0', '1']

# %%
sample = val_ds.take(1).shuffle(1)
sample
# Out:
# <ShuffleDataset shapes: ((None, 150, 150, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
# plot 12 images from the training set with thier  class names
plt.figure(figsize=(16,16))
for img, labels in train_ds.take(1):
    for i in range(12):
        x = plt.subplot(4, 4, i + 1 )
        # tf.Tensor ( data set)
        im = img[i].numpy().astype('uint8') # cast to unit8 type without losing much pixels
        plt.imshow(im)
        class_name = train_ds.class_names[labels[i]]
        plt.title(class_name)

# %%
train_ds = train_ds.shuffle(100)
val_ds = val_ds.shuffle(100)

# %%
train_ds = train_ds.map(lambda x, y: (Rescaling(1./255)(x), y))
val_ds = val_ds.map(lambda x, y: (Rescaling(1./255)(x), y))

# %%
model = Sequential()

pretrained_model= tf.keras.applications.VGG16(include_top=False,
                   input_shape=(150,150,3),
                   pooling='avg',classes=NUM_CLS,
                   weights='imagenet')
for layer in pretrained_model.layers:
        layer.trainable=False

model.add(pretrained_model)

# %%
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(NUM_CLS, activation='sigmoid'))

# %%
opt = Adam(lr=0.001)
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer = opt,
    metrics=['accuracy'],
)
# Out:
# C:\Users\EN7\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 128)               65664
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 14,780,610
# Trainable params: 65,922
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
history = model.fit(train_ds, validation_data=val_ds, epochs=50)
# Out:
# Epoch 1/50
# 130/130 [==============================] - 161s 1s/step - loss: 0.5550 - accuracy: 0.7197 - val_loss: 0.5279 - val_accuracy: 0.7603
# Epoch 2/50
# 130/130 [==============================] - 164s 1s/step - loss: 0.4778 - accuracy: 0.7780 - val_loss: 0.4828 - val_accuracy: 0.7892
# Epoch 3/50
# 130/130 [==============================] - 158s 1s/step - loss: 0.4506 - accuracy: 0.7922 - val_loss: 0.4614 - val_accuracy: 0.7931
# Epoch 4/50
# 130/130 [==============================] - 158s 1s/step - loss: 0.4255 - accuracy: 0.8071 - val_loss: 0.4871 - val_accuracy: 0.7902
# Epoch 5/50
# 130/130 [==============================] - 160s 1s/step - loss: 0.4150 - accuracy: 0.8145 - val_loss: 0.4504 - val_accuracy: 0.8037
# Epoch 6/50
# 130/130 [==============================] - 158s 1s/step - loss: 0.3932 - accuracy: 0.8340 - val_loss: 0.4465 - val_accuracy: 0.8075
# Epoch 7/50
# 130/130 [==============================] - 158s 1s/step - loss: 0.3849 - accuracy: 0.8335 - val_loss: 0.4490 - val_accuracy: 0.8075
# Epoch 8/50
# 130/130 [==============================] - 159s 1s/step - loss: 0.3694 - accuracy: 0.8436 - val_loss: 0.4937 - val_accuracy: 0.7873
# Epoch 9/50
# 130/130 [==============================] - 160s 1s/step - loss: 0.3533 - accuracy: 0.8513 - val_loss: 0.4409 - val_accuracy: 0.8219
# Epoch 10/50
# 130/130 [==============================] - 162s 1s/step - loss: 0.3419 - accuracy: 0.8581 - val_loss: 0.4599 - val_accuracy: 0.8114
# Epoch 11/50
# 130/130 [==============================] - 160s 1s/step - loss: 0.3266 - accuracy: 0.8634 - val_loss: 0.4369 - val_accuracy: 0.8142
# Epoch 12/50
# 130/130 [==============================] - 161s 1s/step - loss: 0.3258 - accuracy: 0.8619 - val_loss: 0.4325 - val_accuracy: 0.8248
# Epoch 13/50
# 130/130 [==============================] - 160s 1s/step - loss: 0.3050 - accuracy: 0.8756 - val_loss: 0.4417 - val_accuracy: 0.8219
# Epoch 14/50
# 130/130 [==============================] - 160s 1s/step - loss: 0.2965 - accuracy: 0.8792 - val_loss: 0.4486 - val_accuracy: 0.8162
# Epoch 15/50
# 130/130 [==============================] - 158s 1s/step - loss: 0.2776 - accuracy: 0.8838 - val_loss: 0.5125 - val_accuracy: 0.7892
# Epoch 16/50
# 130/130 [==============================] - 160s 1s/step - loss: 0.2695 - accuracy: 0.8942 - val_loss: 0.4598 - val_accuracy: 0.8219
# Epoch 17/50
# 130/130 [==============================] - 160s 1s/step - loss: 0.2534 - accuracy: 0.8994 - val_loss: 0.4330 - val_accuracy: 0.8383
# Epoch 18/50
# 130/130 [==============================] - 159s 1s/step - loss: 0.2428 - accuracy: 0.9038 - val_loss: 0.4958 - val_accuracy: 0.8152
# Epoch 19/50
# 130/130 [==============================] - 159s 1s/step - loss: 0.2236 - accuracy: 0.9172 - val_loss: 0.4380 - val_accuracy: 0.8402
# Epoch 20/50
# 130/130 [==============================] - 160s 1s/step - loss: 0.2184 - accuracy: 0.9213 - val_loss: 0.4727 - val_accuracy: 0.8219
# Epoch 21/50
# 130/130 [==============================] - 163s 1s/step - loss: 0.2041 - accuracy: 0.9252 - val_loss: 0.4665 - val_accuracy: 0.8364
# Epoch 22/50
# 130/130 [==============================] - 161s 1s/step - loss: 0.1913 - accuracy: 0.9326 - val_loss: 0.4774 - val_accuracy: 0.8335
# Epoch 23/50
# 130/130 [==============================] - 160s 1s/step - loss: 0.1825 - accuracy: 0.9355 - val_loss: 0.4737 - val_accuracy: 0.8287
# Epoch 24/50
# 130/130 [==============================] - 161s 1s/step - loss: 0.1714 - accuracy: 0.9437 - val_loss: 0.4619 - val_accuracy: 0.8383
# Epoch 25/50
# 130/130 [==============================] - 159s 1s/step - loss: 0.1718 - accuracy: 0.9372 - val_loss: 0.4816 - val_accuracy: 0.8296
# Epoch 26/50
# 130/130 [==============================] - 158s 1s/step - loss: 0.1536 - accuracy: 0.9526 - val_loss: 0.4825 - val_accuracy: 0.8325
# Epoch 27/50
# 130/130 [==============================] - 161s 1s/step - loss: 0.1459 - accuracy: 0.9514 - val_loss: 0.4758 - val_accuracy: 0.8431
# Epoch 28/50
# 130/130 [==============================] - 160s 1s/step - loss: 0.1331 - accuracy: 0.9625 - val_loss: 0.5517 - val_accuracy: 0.8210
# Epoch 29/50
# 130/130 [==============================] - 159s 1s/step - loss: 0.1261 - accuracy: 0.9644 - val_loss: 0.5069 - val_accuracy: 0.8441
# Epoch 30/50
# 130/130 [==============================] - 160s 1s/step - loss: 0.1185 - accuracy: 0.9649 - val_loss: 0.5312 - val_accuracy: 0.8393
# Epoch 31/50
# 130/130 [==============================] - 161s 1s/step - loss: 0.1067 - accuracy: 0.9740 - val_loss: 0.5232 - val_accuracy: 0.8422
# Epoch 32/50
# 130/130 [==============================] - 158s 1s/step - loss: 0.1170 - accuracy: 0.9637 - val_loss: 0.5072 - val_accuracy: 0.8431
# Epoch 33/50
# 130/130 [==============================] - 161s 1s/step - loss: 0.0961 - accuracy: 0.9755 - val_loss: 0.5559 - val_accuracy: 0.8268
# Epoch 34/50
# 130/130 [==============================] - 161s 1s/step - loss: 0.0867 - accuracy: 0.9820 - val_loss: 0.5600 - val_accuracy: 0.8422
# Epoch 35/50
# 130/130 [==============================] - 161s 1s/step - loss: 0.0937 - accuracy: 0.9726 - val_loss: 0.5396 - val_accuracy: 0.8335
# Epoch 36/50
# 130/130 [==============================] - 159s 1s/step - loss: 0.0763 - accuracy: 0.9841 - val_loss: 0.5475 - val_accuracy: 0.8364
# Epoch 37/50
# 130/130 [==============================] - 165s 1s/step - loss: 0.0733 - accuracy: 0.9851 - val_loss: 0.5783 - val_accuracy: 0.8383
# Epoch 38/50
# 130/130 [==============================] - 161s 1s/step - loss: 0.0662 - accuracy: 0.9880 - val_loss: 0.5590 - val_accuracy: 0.8354
# Epoch 39/50
# 130/130 [==============================] - 157s 1s/step - loss: 0.0621 - accuracy: 0.9906 - val_loss: 0.5707 - val_accuracy: 0.8422
# Epoch 40/50
# 130/130 [==============================] - 159s 1s/step - loss: 0.0533 - accuracy: 0.9923 - val_loss: 0.5962 - val_accuracy: 0.8402
# Epoch 41/50
# 130/130 [==============================] - 157s 1s/step - loss: 0.0509 - accuracy: 0.9930 - val_loss: 0.6087 - val_accuracy: 0.8422
# Epoch 42/50
# 130/130 [==============================] - 157s 1s/step - loss: 0.0469 - accuracy: 0.9937 - val_loss: 0.6024 - val_accuracy: 0.8450
# Epoch 43/50
# 130/130 [==============================] - 156s 1s/step - loss: 0.0447 - accuracy: 0.9947 - val_loss: 0.6362 - val_accuracy: 0.8431
# Epoch 44/50
# 130/130 [==============================] - 157s 1s/step - loss: 0.0422 - accuracy: 0.9945 - val_loss: 0.6524 - val_accuracy: 0.8402
# Epoch 45/50
# 130/130 [==============================] - 157s 1s/step - loss: 0.0370 - accuracy: 0.9969 - val_loss: 0.6535 - val_accuracy: 0.8402
# Epoch 46/50
# 130/130 [==============================] - 159s 1s/step - loss: 0.0332 - accuracy: 0.9974 - val_loss: 0.6519 - val_accuracy: 0.8402
# Epoch 47/50
# 130/130 [==============================] - 158s 1s/step - loss: 0.0313 - accuracy: 0.9971 - val_loss: 0.6516 - val_accuracy: 0.8364
# Epoch 48/50
# 130/130 [==============================] - 158s 1s/step - loss: 0.0311 - accuracy: 0.9976 - val_loss: 0.6651 - val_accuracy: 0.8402
# Epoch 49/50
# 130/130 [==============================] - 184s 1s/step - loss: 0.0256 - accuracy: 0.9983 - val_loss: 0.6897 - val_accuracy: 0.8412
# Epoch 50/50
# 130/130 [==============================] - 157s 1s/step - loss: 0.0223 - accuracy: 0.9990 - val_loss: 0.6879 - val_accuracy: 0.8441

# %%
# plot history 
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from keras.applications import mobilenet_v2
from keras.preprocessing import image


def prepare_image(img_path):

    img = image.load_img(img_path, target_size=(150, 150))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = mobilenet_v2.preprocess_input(x)
    return x
x = prepare_image(path)

# %%
p = new_model.predict(x)

# %%
def get_class_name(pred):
    classes_vals = pred.tolist()[0]
    hashtable = {}
    for i,j in zip(classes_vals, CLS_NAMES):
        hashtable[j] = i
    return hashtable

# %%
get_class_name(p)
# Out:
# {'0': 0.9999258518218994, '1': 0.0008122920989990234}

# %%
# save model 
model.save('SmokingModelVGG16.h5')

# %%
# Recreate the exact same model, including its weights and the optimizer
new_model = tf.keras.models.load_model('SmokingModelVGG16.h5')

# %%
new_model.predict(x)
# Out:
# array([[9.999820e-01, 6.727679e-05]], dtype=float32)
