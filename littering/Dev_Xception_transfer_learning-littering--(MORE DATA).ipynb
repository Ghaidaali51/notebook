# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from keras.layers import (
    Dense, Conv2D, GlobalAveragePooling2D, MaxPooling2D, Flatten, Rescaling, Input
) 
from keras.models import Sequential
# tensorflow 
from tensorflow.keras.utils import image_dataset_from_directory
import tensorflow as tf

# utils 
import numpy as np 
import random 

# vis
# import seaborn as sns
#import cv2 
import matplotlib.pyplot as plt


# sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
# load data from directory

# %%
img_size = (150, 150)

def img_to_tf_dataset(path , 
                      labels='inferred', 
                      img_size=img_size,
                      subset="training"):
    """ Fetch images assign label to them based on folders tree"""
    dataset = image_dataset_from_directory(
        directory=r"C:\Users\EN7\Desktop\pics\MOREDATA",
        labels=labels , # labels generated from folder structure
        image_size=img_size,
        validation_split=0.2,
        subset=subset,
        seed=123,
        # default batch size 32
    )
    return dataset

# %%
train_ds = img_to_tf_dataset('data')
# Out:
# Found 4820 files belonging to 2 classes.
# Using 3856 files for training.

# %%
val_ds = img_to_tf_dataset('data', subset='validation')
# Out:
# Found 4820 files belonging to 2 classes.
# Using 964 files for validation.

# %%
NUM_CLS = len(val_ds.class_names)
CLS_NAMES = val_ds.class_names
CLS_NAMES
# Out:
# ['0', '1']

# %%
sample = val_ds.take(1).shuffle(1)
sample
# Out:
# <ShuffleDataset element_spec=(TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
# plot 12 images from the training set with thier  class names
plt.figure(figsize=(16,16))
for img, labels in train_ds.take(1):
    for i in range(12):
        x = plt.subplot(4, 4, i + 1 )
        # tf.Tensor ( data set)
        im = img[i].numpy().astype('uint8') # cast to unit8 type without losing much pixels
        plt.imshow(im)
        class_name = train_ds.class_names[labels[i]]
        plt.title(class_name)

# %%
train_ds = train_ds.shuffle(100)
val_ds = val_ds.shuffle(100)

# %%
train_ds = train_ds.map(lambda x, y: (Rescaling(1./255)(x), y))
val_ds = val_ds.map(lambda x, y: (Rescaling(1./255)(x), y))

# %%
model = Sequential()

pretrained_model= tf.keras.applications.Xception(include_top=False,
                   input_shape=(150,150,3),
                   pooling='avg',classes=NUM_CLS,
                   weights='imagenet')
for layer in pretrained_model.layers:
        layer.trainable=False

model.add(pretrained_model)

# %%
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(NUM_CLS, activation='sigmoid'))

# %%
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer = "adam",
    metrics=['accuracy'],
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 2048)              20861480
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 21,124,010
# Trainable params: 262,530
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
history = model.fit(train_ds, validation_data=val_ds, epochs=100)
# Out:
# Epoch 1/100
# 121/121 [==============================] - 93s 596ms/step - loss: 0.1258 - accuracy: 0.9546 - val_loss: 0.1450 - val_accuracy: 0.9492
# Epoch 2/100
# 121/121 [==============================] - 93s 600ms/step - loss: 0.0475 - accuracy: 0.9855 - val_loss: 0.0988 - val_accuracy: 0.9647
# Epoch 3/100
# 121/121 [==============================] - 93s 600ms/step - loss: 0.0295 - accuracy: 0.9896 - val_loss: 0.1073 - val_accuracy: 0.9720
# Epoch 4/100
# 121/121 [==============================] - 93s 600ms/step - loss: 0.0163 - accuracy: 0.9948 - val_loss: 0.1260 - val_accuracy: 0.9678
# Epoch 5/100
# 121/121 [==============================] - 93s 600ms/step - loss: 0.0078 - accuracy: 0.9987 - val_loss: 0.1426 - val_accuracy: 0.9668
# Epoch 6/100
# 121/121 [==============================] - 93s 600ms/step - loss: 0.0041 - accuracy: 0.9997 - val_loss: 0
# 121/121 [==============================] - 93s 597ms/step - loss: 1.9321e-06 - accuracy: 1.0000 - val_loss: 0.4247 - val_accuracy: 0.9658
# Epoch 87/100
# 121/121 [==============================] - 93s 599ms/step - loss: 1.8217e-06 - accuracy: 1.0000 - val_loss: 0.4272 - val_accuracy: 0.9658
# Epoch 88/100
# 121/121 [==============================] - 93s 597ms/step - loss: 1.6842e-06 - accuracy: 1.0000 - val_loss: 0.4297 - val_accuracy: 0.9658
# Epoch 89/100
# 121/121 [==============================] - 93s 599ms/step - loss: 1.5705e-06 - accuracy: 1.0000 - val_loss: 0.4328 - val_accuracy: 0.9658
# Epoch 90/100
# 121/121 [==============================] - 94s 610ms/step - loss: 1.4588e-06 - accuracy: 1.0000 - val_loss: 0.4349 - val_accuracy: 0.9658
# Epoch 91/100
# 121/121 [==============================] - 95s 616ms/step - loss: 1.3733e-06 - accuracy: 1.0000 - val_loss: 0.4374 - val_accuracy: 0.9658
# Epoch 92/100
# 121/121 [==============================] - 95s 615ms/step - loss: 1.2767e-06 - accuracy: 1.0000 - val_loss: 0.4403 - val_accuracy: 0.9658
# Epoch 93/100
# 121/121 [==============================] - 95s 616ms/step - loss: 1.1950e-06 - accuracy: 1.0000 - val_loss: 0.4428 - val_accuracy: 0.9658
# Epoch 94/100
# 121/121 [==============================] - 93s 597ms/step - loss: 1.0985e-06 - accuracy: 1.0000 - val_loss: 0.4455 - val_accuracy: 0.9658
# Epoch 95/100
# 121/121 [==============================] - 93s 598ms/step - loss: 1.0451e-06 - accuracy: 1.0000 - val_loss: 0.4486 - val_accuracy: 0.9658
# Epoch 96/100
# 121/121 [==============================] - 93s 601ms/step - loss: 9.8145e-07 - accuracy: 1.0000 - val_loss: 0.4505 - val_accuracy: 0.9658
# Epoch 97/100
# 121/121 [==============================] - 95s 614ms/step - loss: 9.0235e-07 - accuracy: 1.0000 - val_loss: 0.4536 - val_accuracy: 0.9658
# Epoch 98/100
# 121/121 [==============================] - 93s 601ms/step - loss: 8.5628e-07 - accuracy: 1.0000 - val_loss: 0.4565 - val_accuracy: 0.9658
# Epoch 99/100
# 121/121 [==============================] - 95s 618ms/step - loss: 7.8856e-07 - accuracy: 1.0000 - val_loss: 0.4591 - val_accuracy: 0.9658
# Epoch 100/100
# 121/121 [==============================] - 93s 599ms/step - loss: 7.3926e-07 - accuracy: 1.0000 - val_loss: 0.4615 - val_accuracy: 0.9658

# %%
# plot history 
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
from keras.applications import mobilenet_v2
from keras.preprocessing import image


def prepare_image(img_path):

    img = image.load_img(img_path, target_size=(150, 150))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = mobilenet_v2.preprocess_input(x)
    return x
x = prepare_image(r'C:\Users\EN7\Desktop\pics\test\200.jpg')

# %%
p = model.predict(x)

# %%
def get_class_name(pred):
    classes_vals = pred.tolist()[0]
    hashtable = {}
    for i,j in zip(classes_vals, CLS_NAMES):
        hashtable[j] = i
    return hashtable

# %%
get_class_name(p)
# Out:
# {'0': 0.9999982118606567, '1': 1.0339969094275148e-06}

# %%
# save model 

model.save('litteringXceptionMOREDATA.h5')

# %%
# Recreate the exact same model, including its weights and the optimizer
new_model = tf.keras.models.load_model('litteringXceptionMOREDATA.h5')

# %%
new_model.predict(x)
# Out:
# WARNING:tensorflow:5 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001E4E8DC64C0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[9.9999821e-01, 1.0339969e-06]], dtype=float32)
